# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pickle

# %%
data = pd.read_csv('Housing.csv')

# %%
data.tail(-5)
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 5    10850000   7500         3          3        1      yes        no
# 6    10150000   8580         4          3        4      yes        no
# 7    10150000  16200         5          3        2      yes        no
# 8     9870000   8100         4          1        2      yes       yes
# 9     9800000   5750         3          2        4      yes       yes
# ..        ...    ...       ...        ...      ...      ...       ...
# 540   1820000   3000         2          1        1      yes        no
# 541   1767150   2400         3          1        1       no        no
# 542   1750000   3620         2          1        1      yes        no
# 543   1750000   2910         3          1        1       no        no
# 544   1750000   3850         3          1        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 5        yes              no             yes        2      yes
# 6         no              no             yes        2      yes
# 7         no              no              no        0       no
# 8        yes              no             yes        2      yes
# 9         no              no             yes        1      yes
# ..       ...             ...             ...      ...      ...
# 540      yes              no              no        2       no
# 541       no              no              no        0       no
# 542       no              no              no        0       no
# 543       no              no              no        0       no
# 544       no              no              no        0       no
#
#     furnishingstatus
# 5     semi-furnished
# 6     semi-furnished
# 7        unfurnished
# 8          furnished
# 9        unfurnished
# ..               ...
# 540      unfurnished
# 541   semi-furnished
# 542      unfurnished
# 543        furnished
# 544      unfurnished
#
# [540 rows x 13 columns]

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
data = pd.get_dummies(data, columns=['mainroad',
       'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
        'prefarea', 'furnishingstatus'])

# %%
X = data.drop(columns=['price'])

# %%
Y = data['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pickle.dump(model, open('house_predict_model.pkl','wb'))

# %%
import numpy as np
x_test = np.array(X_test)
print(np.array(X_test))
y_test = np.array(y_test)
print(np.array(y_test))
# Out:
# [[6000 3 2 ... False False True]
#  [7600 4 1 ... True False False]
#  [5400 3 1 ... False True False]
#  ...
#  [4600 2 2 ... False True False]
#  [3000 2 1 ... True False False]
#  [5800 3 1 ... False True False]]
# [ 5775000  5040000  4025000  4025000  3395000  5600000  7000000 10150000
#   3745000  7245000  3430000  4767000  6629000  6790000  8400000  4340000
#   5803000  3150000  8463000  2604000  4935000  3150000  9800000  2380000
#   4760000  3773000  6510000  4550000  4900000  5243000 12250000  6195000
#   4235000  6930000  5250000  8645000  5460000  6790000  2450000  6650000
#   5425000  4200000  7210000  4690000  2870000  3332000  3500000  3150000
#   5145000  6615000  5250000  2450000  8120000  3430000  8295000  7560000
#   7700000  3150000  4277000  3703000  3500000  3500000  7700000  5950000
#   5600000  3360000  5880000  2940000  8400000  2590000  5600000  3570000
#   4340000  5880000  3010000  2310000  2450000  7560000  4305000  4130000
#   4007500  3150000  3360000  3325000  7350000  3290000  4060000  3220000
#   4382000  6650000  3430000  5460000  3290000  2660000  8645000  4200000
#   4200000  5040000  5215000  3773000 13300000  3710000  7350000  8400000
#   2940000  3640000  5285000  3640000  4200000]

# %%
model = pickle.load(open('house_predict_model.pkl','rb'))
predicted_price = model.predict(X_test)

print(predicted_price[0])
# Out:
# 6512698.506546538
